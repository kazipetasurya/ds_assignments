# %%
import urllib.request
import io
import gzip
import pandas as pd
import numpy as np
import time
import requests
from pandas.io.json import json_normalize
import json
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn import ensemble, preprocessing
from sklearn.model_selection import train_test_split
import sklearn.metrics

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Downloading the file with City ID and population data from the OpenWeatherMapData

# %%
url = "http://bulk.openweathermap.org/sample/current.city.list.json.gz"
outfile_path = "current_city.json"

# %%
response = urllib.request.urlopen(url)
compressed_file = io.BytesIO(response.read())
decompressed_file = gzip.GzipFile(fileobj=compressed_file)

with open(outfile_path, 'wb') as outfile:
    outfile.write(decompressed_file.read())

# %%
data = json.load(open(outfile_path))

# %%
# Sample format of the output
data[0]
# Out:
# {'coord': {'lat': 34.790878, 'lon': 48.570728},
#  'country': 'IR',
#  'geoname': {'cl': 'P', 'code': 'PPL', 'parent': 132142},
#  'id': 14256,
#  'langs': [{'de': 'Azad Shahr'}, {'fa': 'آزادشهر'}],
#  'name': 'Azadshahr',
#  'stat': {'level': 1.0, 'population': 514102},
#  'stations': [{'dist': 9, 'id': 7030, 'kf': 1}],
#  'zoom': 10}

# %%
# Transforming json to dataframe
df = pd.DataFrame(index = np.arange(len(data)), columns = ['id', 'city', 'country', 'population'])
for i in range(len(data)):
    df['id'][i] = data[i]['id']
    df['city'][i] = data[i]['name']
    df['country'][i] = data[i]['country']
    df['population'][i] = data[i]['stat']['population']

# %%
df = df.sort_values(['population'], ascending = False)
df = df.reset_index()

# %%
# Selecting only the top 100 cities based on population
top100 = df[0:100]
# saving the results
# top100.to_csv('~/top100.csv')

# %%
top100 = pd.read_csv('~/top100.csv')

# %%
# View the sample data of top cities
top100.head(3)
# Out:
#    Unnamed: 0  index       id      city country  population
# 0           0   8526  1796236  Shanghai      CN    14608512
# 1           1   9085  1850144  Tōkyō-to      JP    12445327
# 2           2   4022  1174872   Karachi      PK    11624219

# %% [markdown]
# ### Classification model of Weather bit data for the top 100 cities

# %%
base_url = "https://api.weatherbit.io/v2.0/forecast/3hourly?city="
key = "&key=fb160a43539c4f65886ca58f5aba9b94"

# %%
cities = top100.city.values

# %%
# Fetching the weather data for top 50 cities
res_bit = []
for i in range(len(cities[0:50])):
    res_bit.append(requests.get(base_url + str(cities[i]) + key).text)
    time.sleep(0.5)

# %%
# Checking the sample response
json.loads(res_bit[1])
# Out:
# {'city_name': 'Tōkyō',
#  'country_code': 'JP',
#  'data': [{'app_temp': 9.8,
#    'clouds': 3,
#    'datetime': '2018-03-11:15',
#    'dewpt': 3,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1012,
#    'rh': 62.5,
#    'slp': 1019.5,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 9.8,
#    'ts': 1520780400,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01n'},
#    'wind_cdir': 'NE',
#    'wind_cdir_full': 'northeast',
#    'wind_dir': 45,
#    'wind_spd': 1.4},
#   {'app_temp': 8.5,
#    'clouds': 1,
#    'datetime': '2018-03-11:18',
#    'dewpt': -4.1,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1013,
#    'rh': 40.6,
#    'slp': 1020,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 8.5,
#    'ts': 1520791200,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01n'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 0.6},
#   {'app_temp': 7.3,
#    'clouds': 1,
#    'datetime': '2018-03-11:21',
#    'dewpt': -5.4,
#    'dhi': 226.9,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1014.5,
#    'rh': 40,
#    'slp': 1021.5,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 7.3,
#    'ts': 1520802000,
#    'uv': 2,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01d'},
#    'wind_cdir': 'NE',
#    'wind_cdir_full': 'northeast',
#    'wind_dir': 45,
#    'wind_spd': 0.1},
#   {'app_temp': 8.8,
#    'clouds': 3,
#    'datetime': '2018-03-12:00',
#    'dewpt': -6.3,
#    'dhi': 748.7,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1016,
#    'rh': 33.7,
#    'slp': 1022.5,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 8.8,
#    'ts': 1520812800,
#    'uv': 5,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01d'},
#    'wind_cdir': 'NE',
#    'wind_cdir_full': 'northeast',
#    'wind_dir': 45,
#    'wind_spd': 2.4},
#   {'app_temp': 11.3,
#    'clouds': 5,
#    'datetime': '2018-03-12:03',
#    'dewpt': -5.9,
#    'dhi': 823.3,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1016,
#    'rh': 29.4,
#    'slp': 1022,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 11.3,
#    'ts': 1520823600,
#    'uv': 7,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01d'},
#    'wind_cdir': 'NE',
#    'wind_cdir_full': 'northeast',
#    'wind_dir': 45,
#    'wind_spd': 4},
#   {'app_temp': 12.8,
#    'clouds': 2,
#    'datetime': '2018-03-12:06',
#    'dewpt': -1.8,
#    'dhi': 435.3,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1015,
#    'rh': 36.2,
#    'slp': 1021.5,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 12.8,
#    'ts': 1520834400,
#    'uv': 2,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01d'},
#    'wind_cdir': 'NE',
#    'wind_cdir_full': 'northeast',
#    'wind_dir': 45,
#    'wind_spd': 0.8},
#   {'app_temp': 12,
#    'clouds': 0,
#    'datetime': '2018-03-12:09',
#    'dewpt': 1.4,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1016,
#    'rh': 48.3,
#    'slp': 1023.5,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 12,
#    'ts': 1520845200,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01n'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 1.1},
#   {'app_temp': 11.5,
#    'clouds': 0,
#    'datetime': '2018-03-12:12',
#    'dewpt': 3.6,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1017.5,
#    'rh': 58.2,
#    'slp': 1025,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 11.5,
#    'ts': 1520856000,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01n'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 2.1},
#   {'app_temp': 10.5,
#    'clouds': 0,
#    'datetime': '2018-03-12:15',
#    'dewpt': 4.5,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1017.5,
#    'rh': 66.2,
#    'slp': 1025,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 10.5,
#    'ts': 1520866800,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01n'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 2.9},
#   {'app_temp': 9.8,
#    'clouds': 0,
#    'datetime': '2018-03-12:18',
#    'dewpt': 4.3,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1017,
#    'rh': 68.6,
#    'slp': 1024,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 9.8,
#    'ts': 1520877600,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01n'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 2.7},
#   {'app_temp': 8.8,
#    'clouds': 0,
#    'datetime': '2018-03-12:21',
#    'dewpt': 2.8,
#    'dhi': 228.5,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1017,
#    'rh': 66,
#    'slp': 1024,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 8.8,
#    'ts': 1520888400,
#    'uv': 2,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01d'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 2},
#   {'app_temp': 11.3,
#    'clouds': 0,
#    'datetime': '2018-03-13:00',
#    'dewpt': 2.2,
#    'dhi': 764.5,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1018,
#    'rh': 53.4,
#    'slp': 1024,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 11.3,
#    'ts': 1520899200,
#    'uv': 6,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01d'},
#    'wind_cdir': 'NE',
#    'wind_cdir_full': 'northeast',
#    'wind_dir': 45,
#    'wind_spd': 0.6},
#   {'app_temp': 15.8,
#    'clouds': 0,
#    'datetime': '2018-03-13:03',
#    'dewpt': 0.7,
#    'dhi': 852.7,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1016,
#    'rh': 35.9,
#    'slp': 1022.5,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 15.8,
#    'ts': 1520910000,
#    'uv': 8,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01d'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 0.5},
#   {'app_temp': 17.5,
#    'clouds': 0,
#    'datetime': '2018-03-13:06',
#    'dewpt': 1,
#    'dhi': 441.4,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1014,
#    'rh': 32.8,
#    'slp': 1020.5,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 17.5,
#    'ts': 1520920800,
#    'uv': 2,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01d'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 2.2},
#   {'app_temp': 15.8,
#    'clouds': 0,
#    'datetime': '2018-03-13:09',
#    'dewpt': 3.7,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1014,
#    'rh': 44.5,
#    'slp': 1021.5,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 15.8,
#    'ts': 1520931600,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01n'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 4.2},
#   {'app_temp': 14,
#    'clouds': 0,
#    'datetime': '2018-03-13:12',
#    'dewpt': 4.6,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1014.5,
#    'rh': 53,
#    'slp': 1023,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 14,
#    'ts': 1520942400,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01n'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 3.8},
#   {'app_temp': 13,
#    'clouds': 0,
#    'datetime': '2018-03-13:15',
#    'dewpt': 3.5,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1014.5,
#    'rh': 52.4,
#    'slp': 1023,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 13,
#    'ts': 1520953200,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01n'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 3.1},
#   {'app_temp': 11.8,
#    'clouds': 0,
#    'datetime': '2018-03-13:18',
#    'dewpt': 1.4,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1014,
#    'rh': 48.9,
#    'slp': 1022,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 11.8,
#    'ts': 1520964000,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01n'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 2.7},
#   {'app_temp': 11.3,
#    'clouds': 0,
#    'datetime': '2018-03-13:21',
#    'dewpt': -1.3,
#    'dhi': 228.5,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1014.5,
#    'rh': 41.6,
#    'slp': 1022.5,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 11.3,
#    'ts': 1520974800,
#    'uv': 2,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01d'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 1.7},
#   {'app_temp': 14.8,
#    'clouds': 0,
#    'datetime': '2018-03-14:00',
#    'dewpt': -2.9,
#    'dhi': 764.5,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1016.5,
#    'rh': 29.4,
#    'slp': 1023,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 14.8,
#    'ts': 1520985600,
#    'uv': 6,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01d'},
#    'wind_cdir': 'NE',
#    'wind_cdir_full': 'northeast',
#    'wind_dir': 45,
#    'wind_spd': 1.3},
#   {'app_temp': 18.3,
#    'clouds': 0,
#    'datetime': '2018-03-14:03',
#    'dewpt': -4.4,
#    'dhi': 852.7,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1016,
#    'rh': 21,
#    'slp': 1022,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 18.3,
#    'ts': 1520996400,
#    'uv': 8,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01d'},
#    'wind_cdir': 'NE',
#    'wind_cdir_full': 'northeast',
#    'wind_dir': 45,
#    'wind_spd': 2.4},
#   {'app_temp': 18.9,
#    'clouds': 0,
#    'datetime': '2018-03-14:06',
#    'dewpt': -3.3,
#    'dhi': 441.4,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1014.5,
#    'rh': 20.1,
#    'slp': 1021,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 20.3,
#    'ts': 1521007200,
#    'uv': 2,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01d'},
#    'wind_cdir': 'NE',
#    'wind_cdir_full': 'northeast',
#    'wind_dir': 45,
#    'wind_spd': 1.6},
#   {'app_temp': 17.7,
#    'clouds': 0,
#    'datetime': '2018-03-14:09',
#    'dewpt': 3.5,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1015.5,
#    'rh': 36.2,
#    'slp': 1022.5,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 18.8,
#    'ts': 1521018000,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01n'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 0},
#   {'app_temp': 16.5,
#    'clouds': 0,
#    'datetime': '2018-03-14:12',
#    'dewpt': 6.9,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1017,
#    'rh': 53,
#    'slp': 1024,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 16.5,
#    'ts': 1521028800,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01n'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 1.2},
#   {'app_temp': 15,
#    'clouds': 0,
#    'datetime': '2018-03-14:15',
#    'dewpt': 6.4,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1016.5,
#    'rh': 56.5,
#    'slp': 1024,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 15,
#    'ts': 1521039600,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01n'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 1.1},
#   {'app_temp': 14,
#    'clouds': 0,
#    'datetime': '2018-03-14:18',
#    'dewpt': 4.3,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1016.5,
#    'rh': 52.2,
#    'slp': 1023.5,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 14,
#    'ts': 1521050400,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01n'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 0.9},
#   {'app_temp': 13,
#    'clouds': 0,
#    'datetime': '2018-03-14:21',
#    'dewpt': 2,
#    'dhi': 228.5,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1017,
#    'rh': 47.3,
#    'slp': 1024,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 13,
#    'ts': 1521061200,
#    'uv': 2,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01d'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 1},
#   {'app_temp': 16,
#    'clouds': 0,
#    'datetime': '2018-03-15:00',
#    'dewpt': 1.1,
#    'dhi': 764.5,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1017.5,
#    'rh': 36.4,
#    'slp': 1023.5,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 16,
#    'ts': 1521072000,
#    'uv': 6,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01d'},
#    'wind_cdir': 'NE',
#    'wind_cdir_full': 'northeast',
#    'wind_dir': 45,
#    'wind_spd': 1},
#   {'app_temp': 18.2,
#    'clouds': 0,
#    'datetime': '2018-03-15:03',
#    'dewpt': 4,
#    'dhi': 852.7,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1015.5,
#    'rh': 36.3,
#    'slp': 1022,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 19.3,
#    'ts': 1521082800,
#    'uv': 8,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01d'},
#    'wind_cdir': 'NE',
#    'wind_cdir_full': 'northeast',
#    'wind_dir': 45,
#    'wind_spd': 1.3},
#   {'app_temp': 19.9,
#    'clouds': 0,
#    'datetime': '2018-03-15:06',
#    'dewpt': 6.1,
#    'dhi': 441.4,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1012.5,
#    'rh': 38.5,
#    'slp': 1019.5,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 20.8,
#    'ts': 1521093600,
#    'uv': 2,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01d'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 1.2},
#   {'app_temp': 17.7,
#    'clouds': 0,
#    'datetime': '2018-03-15:09',
#    'dewpt': 8,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1011.5,
#    'rh': 50.3,
#    'slp': 1019.5,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 18.5,
#    'ts': 1521104400,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01n'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 4.4},
#   {'app_temp': 16.3,
#    'clouds': 0,
#    'datetime': '2018-03-15:12',
#    'dewpt': 9.3,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1012.5,
#    'rh': 63.4,
#    'slp': 1021,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 16.3,
#    'ts': 1521115200,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '800', 'description': 'Clear sky', 'icon': 'c01n'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 6},
#   {'app_temp': 15.3,
#    'clouds': 38,
#    'datetime': '2018-03-15:15',
#    'dewpt': 8.1,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1011.5,
#    'rh': 62.2,
#    'slp': 1019.5,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 15.3,
#    'ts': 1521126000,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '802',
#     'description': 'Scattered clouds',
#     'icon': 'c02n'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 5.2},
#   {'app_temp': 14.5,
#    'clouds': 62,
#    'datetime': '2018-03-15:18',
#    'dewpt': 7.5,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1010,
#    'rh': 62.7,
#    'slp': 1017.5,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 14.5,
#    'ts': 1521136800,
#    'uv': 0,
#    'vis': 10,
#    'weather': {'code': '803', 'description': 'Broken clouds', 'icon': 'c03n'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 4.6},
#   {'app_temp': 14,
#    'clouds': 79,
#    'datetime': '2018-03-15:21',
#    'dewpt': 8.3,
#    'dhi': 103.9,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'pres': 1009.5,
#    'rh': 68.3,
#    'slp': 1017,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 14,
#    'ts': 1521147600,
#    'uv': 2,
#    'vis': 10,
#    'weather': {'code': '803', 'description': 'Broken clouds', 'icon': 'c03d'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 3.9},
#   {'app_temp': 16.3,
#    'clouds': 89,
#    'datetime': '2018-03-16:00',
#    'dewpt': 9.1,
#    'dhi': 295,
#    'pod': 'd',
#    'pop': 0,
#    'precip': 0,
#    'precip6h': 0,
#    'pres': 1010,
#    'rh': 62.6,
#    'slp': 1017,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 16.3,
#    'ts': 1521158400,
#    'uv': 2,
#    'vis': 10,
#    'weather': {'code': '803', 'description': 'Broken clouds', 'icon': 'c03d'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 4.4},
#   {'app_temp': 19,
#    'clouds': 89,
#    'datetime': '2018-03-16:03',
#    'dewpt': 10.5,
#    'dhi': 329.1,
#    'pod': 'd',
#    'pop': 15,
#    'precip': 0.06,
#    'pres': 1008,
#    'rh': 56.2,
#    'slp': 1015.5,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 19.5,
#    'ts': 1521169200,
#    'uv': 2,
#    'vis': 10,
#    'weather': {'code': '803', 'description': 'Broken clouds', 'icon': 'c03d'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 4.1},
#   {'app_temp': 16.3,
#    'clouds': 94,
#    'datetime': '2018-03-16:06',
#    'dewpt': 12.2,
#    'dhi': 155.1,
#    'pod': 'd',
#    'pop': 20,
#    'precip': 2.38,
#    'precip6h': 2.44,
#    'pres': 1007.5,
#    'rh': 76.7,
#    'slp': 1014.5,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 16.3,
#    'ts': 1521180000,
#    'uv': 2,
#    'vis': 5,
#    'weather': {'code': '500', 'description': 'Light rain', 'icon': 'r01d'},
#    'wind_cdir': 'SW',
#    'wind_cdir_full': 'southwest',
#    'wind_dir': 225,
#    'wind_spd': 3.2},
#   {'app_temp': 12.5,
#    'clouds': 100,
#    'datetime': '2018-03-16:09',
#    'dewpt': 9.4,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 45,
#    'precip': 7.38,
#    'pres': 1010.5,
#    'rh': 81.6,
#    'slp': 1016.5,
#    'snow': 0,
#    'snow_depth': 0,
#    'temp': 12.5,
#    'ts': 1521190800,
#    'uv': 0,
#    'vis': 5,
#    'weather': {'code': '500', 'description': 'Light rain', 'icon': 'r01n'},
#    'wind_cdir': 'NE',
#    'wind_cdir_full': 'northeast',
#    'wind_dir': 45,
#    'wind_spd': 9.1},
#   {'app_temp': 10,
#    'clouds': 100,
#    'datetime': '2018-03-16:12',
#    'dewpt': 5.1,
#    'dhi': 0,
#    'pod': 'n',
#    'pop': 35,
#    'precip': 4.5,
#    'precip6h': 11.88,
#    'pres': 1014,
#    'rh': 71.8,
#    'slp': 1018.5,
#    'snow': 0,
#    'snow6h': 0,
#    'snow_depth': 0,
#    'temp': 10,
#    'ts': 1521201600,
#    'uv': 0,
#    'vis': 5,
#    'weather': {'code': '500', 'description': 'Light rain', 'icon': 'r01n'},
#    'wind_cdir': 'NE',
#    'wind_cdir_full': 'northeast',
#    'wind_dir': 45,
#    'wind_spd': 7.4}],
#  'lat': '35.6895',
#  'lon': '139.69171',
#  'state_code': '40',
#  'timezone': 'Asia/Tokyo'}

# %%
# Transforming the data in json format to dataframe
bit_df = pd.DataFrame()
for i in range(len(cities[0:50])):
    temp_json = json.loads(res_bit[i])
    temp_df = pd.DataFrame.from_dict(json_normalize(temp_json['data']), orient='columns')
    temp_df['city'] = temp_json['city_name']
    temp_df['lat'] = temp_json['lat']
    temp_df['lon'] = temp_json['lon']
    temp_df['timezone'] = temp_json['timezone']
    # Dropping redundant columns
    temp_df = temp_df.drop(['weather.code', 'weather.icon', 'wind_cdir_full', 'wind_dir'], axis = 1)
    bit_df = bit_df.append(temp_df, ignore_index = True)

# %%
print (bit_df.shape)
print (bit_df.columns)
# Out:
# (2000, 26)
# Index(['app_temp', 'clouds', 'datetime', 'dewpt', 'dhi', 'pod', 'pop',
#        'precip', 'precip6h', 'pres', 'rh', 'slp', 'snow', 'snow6h',
#        'snow_depth', 'temp', 'ts', 'uv', 'vis', 'weather.description',
#        'wind_cdir', 'wind_spd', 'city', 'lat', 'lon', 'timezone'],
#       dtype='object')

# %%
bit_df['weather.description'].value_counts()
# Out:
# Clear sky                       762
# Scattered clouds                465
# Overcast clouds                 337
# Broken clouds                   227
# Drizzle                          75
# Light rain                       55
# Flurries                         17
# Thunderstorm with light rain     14
# Light Rain                       13
# Haze                             12
# Thunderstorm with drizzle         7
# Moderate rain                     6
# Light snow                        5
# Mix snow/rain                     4
# Fog                               1
# Name: weather.description, dtype: int64

# %%
# bit_df.to_csv('~/weatherbit_data.csv')

# %%
# bit_df = pd.read_csv('~/weatherbit_data.csv')

# %%
df = bit_df

# %%
# Extracting hour from datetime to time of the day as a feature in prediction weather description
df['new_datetime'] = (pd.to_datetime(df['datetime'], format = '%Y-%m-%d:%H'))
df["hour"] = df['new_datetime'].apply(lambda x: x.hour)
df.hour = df['hour'].apply(lambda x: str(x))

# %%
feature_cols = ['app_temp', 'clouds', 'dewpt', 'dhi', 'pod', 'pop',
       'precip', 'pres', 'rh', 'slp', 'snow',
       'snow_depth', 'temp', 'uv', 'vis',
       'wind_cdir', 'wind_spd', 'lat', 'lon', 'hour']
pred_col = ['weather.description']

# %%
X = df[feature_cols]
y = df[pred_col]

# %%
# Label encoding discrete variables
for column in ['pod', 'wind_cdir', 'hour']:
    le = LabelEncoder()
    X[column] = le.fit_transform(X[column])

# %%
# One hot encoding label encoded discrete variables
enc = preprocessing.OneHotEncoder(sparse=False)
columns_to_enc = ['pod', 'wind_cdir', 'hour']
X_enc = X[columns_to_enc]
for var in columns_to_enc:
    enc.fit(X_enc[[var]])
    temp = enc.transform(X_enc[[var]])
    temp = pd.DataFrame(temp,columns=[(var+"_"+str(i)) for i in X_enc[var]
                                .value_counts().index])
    temp = temp.set_index(X_enc.index.values)
    # adding the new One Hot Encoded varibales to the train data frame
    X_enc = pd.concat([X_enc, temp],axis=1)
X = pd.concat([X, X_enc],axis=1)
X = X.drop(columns_to_enc, axis=1)

# %%
# Feature selector to remove low variance features that are either one or zero (on or off) in more than 80% of the samples
from sklearn.feature_selection import VarianceThreshold
sel = VarianceThreshold(threshold=(.8 * (1 - .8)))
X_new = sel.fit_transform(X)

# %%
# Test-Train split using inbuilt function in sklearn
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

# %%
# Fitting a random forest classifier with 100 estimators
rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
# Actual values
rf_output = y_test
# Predicted values
rf_output['preds'] = rf.predict(X_test)

# %%
print ("Accuracy is {0}%".format(sklearn.metrics.accuracy_score(rf_output['weather.description'], rf_output['preds'])*100))
# Out:
# Accuracy is 98.0%

# %% [markdown]
# #### Accuracy of the Random Forest Classifier model is around 98%

# %%
# Sample comparison between actual and predicted values
rf_output[0:10]
# Out:
#      weather.description             preds
# 1860     Overcast clouds   Overcast clouds
# 353        Broken clouds     Broken clouds
# 1333           Clear sky         Clear sky
# 905     Scattered clouds  Scattered clouds
# 1289           Clear sky         Clear sky
# 1273    Scattered clouds  Scattered clouds
# 938      Overcast clouds   Overcast clouds
# 1731           Clear sky         Clear sky
# 65             Clear sky         Clear sky
# 1323           Clear sky         Clear sky
